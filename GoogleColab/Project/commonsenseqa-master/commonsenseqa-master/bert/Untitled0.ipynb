# %%
! pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/Project/commonsenseqa-master/commonsenseqa-master/bert/
# Out:
# CONTRIBUTING.md		    multilingual.md	   run_pretraining.py
# create_pretraining_data.py  optimization.py	   run_squad.py
# extract_features.py	    optimization_test.py   sample_text.txt
# __init__.py		    README.md		   tokenization.py
# LICENSE			    requirements.txt	   tokenization_test.py
# modeling.py		    run_classifier.py	   Untitled0.ipynb
# modeling_test.py	    run_commonsense_qa.py

# %%
# !python "/content/drive/MyDrive/Project/commonsenseqa-master/commonsenseqa-master/bert/run_commonsense_qa.py"
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Project/commonsenseqa-master/commonsenseqa-master/bert/run_commonsense_qa.py", line 15, in <module>
#     import optimization
#   File "/content/drive/MyDrive/Project/commonsenseqa-master/commonsenseqa-master/bert/optimization.py", line 84, in <module>
#     class AdamWeightDecayOptimizer(tf.train.Optimizer):
# AttributeError: module 'tensorflow._api.v2.train' has no attribute 'Optimizer'
